# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('./zinc/history.csv')

# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['loss'], label='Training Loss')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss')
plt.title('ZINC w/o Property Prediction Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('./zinc_properties/history.csv')

# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['loss'], label='Training Loss')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss')
plt.title('ZINC w/ Property Prediction Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('./qm9/history.csv')

# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['loss'], label='Training Loss')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss')
plt.title('QM9 w/o Property Prediction Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('./qm9_properties/history.csv')

# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['loss'], label='Training Loss')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss')
plt.title('QM9 w/ Property Prediction Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('./zinc-michael/history.csv')

# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['loss'], label='Training Loss')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss')
plt.title('ZINC Michael w/o Property Prediction Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('./zinc-michael_properties/history.csv')

# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['loss'], label='Training Loss')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss')
plt.title('ZINC Michael w/ Property Prediction Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('./zinc-michael-ordered/history.csv')

# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['loss'], label='Training Loss')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss')
plt.title('ZINC Michael (ordered SMILES) w/o Property Prediction Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('./zinc-michael-ordered_properties/history.csv')

# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['loss'], label='Training Loss')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss')
plt.title('ZINC Michael (ordered SMILES) w/ Property Prediction Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('./zinc-michael-fragments/history.csv')

# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['loss'], label='Training Loss')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss')
plt.title('ZINC Michael (fragment SMILES) w/o Property Prediction Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('./zinc-michael-fragments_properties/history.csv')

# Plotting the loss curves
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['loss'], label='Training Loss')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss')
plt.title('ZINC Michael (fragment SMILES) w/ Property Prediction Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
