# %%
# tensorflow backend
import tensorflow as tf
# tf.compat.v1.disable_v2_behavior()
from os import environ
environ['KERAS_BACKEND'] = 'tensorflow'
environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# vae stuff
from chemvae.vae_utils import VAEUtils
from chemvae import mol_utils as mu
# import scientific py
import numpy as np
import pandas as pd
# plotting stuff
import matplotlib.pyplot as plt
import matplotlib as mpl
from IPython.display import SVG, display
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore", message=".*From.*:")

# %% [markdown]
# # ZINC models

# %%
vae_zinc = VAEUtils(directory='../models/zinc')
vae_zinc_prop = VAEUtils(directory='../models/zinc_properties')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2026-03-05 14:24:36.141335: W tensorflow/c/c_api.cc:305] Operation '{name:'encoder_norm0_2/moving_mean/Assign' id:4537 op device:{requested: '', assigned: ''} def:{{{node encoder_norm0_2/moving_mean/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](encoder_norm0_2/moving_mean, encoder_norm0_2/moving_mean/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:`implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# `implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# WARNING:tensorflow:Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2026-03-05 14:24:36.561415: W tensorflow/c/c_api.cc:305] Operation '{name:'decoder_dense0_norm_2/moving_mean/Assign' id:5136 op device:{requested: '', assigned: ''} def:{{{node decoder_dense0_norm_2/moving_mean/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](decoder_dense0_norm_2/moving_mean, decoder_dense0_norm_2/moving_mean/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Using standarized functions? True
# Standarization: estimating mu and std values ...
# 2026-03-05 14:24:36.969027: W tensorflow/c/c_api.cc:305] Operation '{name:'z_mean_sample_2/BiasAdd' id:4978 op device:{requested: '', assigned: ''} def:{{{node z_mean_sample_2/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](z_mean_sample_2/MatMul, z_mean_sample_2/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# done!
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2026-03-05 14:24:40.417812: W tensorflow/c/c_api.cc:305] Operation '{name:'z_mean_sample_3/kernel/Assign' id:7030 op device:{requested: '', assigned: ''} def:{{{node z_mean_sample_3/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](z_mean_sample_3/kernel, z_mean_sample_3/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:`implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# `implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# WARNING:tensorflow:Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2026-03-05 14:24:40.877410: W tensorflow/c/c_api.cc:305] Operation '{name:'decoder_dense0_3/bias/Assign' id:7162 op device:{requested: '', assigned: ''} def:{{{node decoder_dense0_3/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](decoder_dense0_3/bias, decoder_dense0_3/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Using standarized functions? True
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2026-03-05 14:24:41.212229: W tensorflow/c/c_api.cc:305] Operation '{name:'reg_property_output_1/kernel/Assign' id:8913 op device:{requested: '', assigned: ''} def:{{{node reg_property_output_1/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](reg_property_output_1/kernel, reg_property_output_1/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Standarization: estimating mu and std values ...
# 2026-03-05 14:24:41.561588: W tensorflow/c/c_api.cc:305] Operation '{name:'z_mean_sample_3/BiasAdd' id:7040 op device:{requested: '', assigned: ''} def:{{{node z_mean_sample_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](z_mean_sample_3/MatMul, z_mean_sample_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# done!

# %% [markdown]
# ## Without property predection

# %%
print("Encoder:")
print(vae_zinc.enc.summary())
print("----------------------------------------------------------")
print("Decoder:")
print(vae_zinc.dec.summary())
# Out:
# Encoder:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_molecule_smi (InputL  [(None, 120, 35)]         0
#  ayer)
#
#  encoder_conv0 (Conv1D)      (None, 112, 9)            2844
#
#  encoder_norm0 (BatchNormal  (None, 112, 9)            36
#  ization)
#
#  encoder_conv1 (Conv1D)      (None, 104, 9)            738
#
#  encoder_norm1 (BatchNormal  (None, 104, 9)            36
#  ization)
#
#  encoder_conv2 (Conv1D)      (None, 94, 10)            1000
#
#  encoder_norm2 (BatchNormal  (None, 94, 10)            40
#  ization)
#
#  flatten (Flatten)           (None, 940)               0
#
#  encoder_dense0 (Dense)      (None, 196)               184436
#
#  dropout (Dropout)           (None, 196)               0
#
#  encoder_dense0_norm (Batch  (None, 196)               784
#  Normalization)
#
#  z_mean_sample (Dense)       (None, 196)               38612
#
# =================================================================
# Total params: 228526 (892.68 KB)
# Trainable params: 228078 (890.93 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# None
# ----------------------------------------------------------
# Decoder:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  decoder_input (InputLayer)  [(None, 196)]                0         []
#
#  decoder_dense0 (Dense)      (None, 196)                  38612     ['decoder_input[0][0]']
#
#  dropout_1 (Dropout)         (None, 196)                  0         ['decoder_dense0[0][0]']
#
#  decoder_dense0_norm (Batch  (None, 196)                  784       ['dropout_1[0][0]']
#  Normalization)
#
#  repeat_vector (RepeatVecto  (None, 120, 196)             0         ['decoder_dense0_norm[0][0]']
#  r)
#
#  decoder_gru0 (GRU)          (None, 120, 488)             1002840   ['repeat_vector[0][0]']
#
#  decoder_gru1 (GRU)          (None, 120, 488)             1430328   ['decoder_gru0[0][0]']
#
#  decoder_gru2 (GRU)          (None, 120, 488)             1430328   ['decoder_gru1[0][0]']
#
#  decoder_true_seq_input (In  [(None, 120, 35)]            0         []
#  putLayer)
#
#  decoder_tgru (TerminalGRU)  (None, None, 35)             56280     ['decoder_gru2[0][0]',
#                                                                      'decoder_true_seq_input[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 3959172 (15.10 MB)
# Trainable params: 3958780 (15.10 MB)
# Non-trainable params: 392 (1.53 KB)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## With property predection

# %%
print("Encoder:")
print(vae_zinc_prop.enc.summary())
print("----------------------------------------------------------")
print("Decoder:")
print(vae_zinc_prop.dec.summary())
print("----------------------------------------------------------")
print("Property Predictor:")
print(vae_zinc_prop.property_predictor.summary())
# Out:
# Encoder:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_molecule_smi (InputL  [(None, 120, 35)]         0
#  ayer)
#
#  encoder_conv0 (Conv1D)      (None, 112, 9)            2844
#
#  encoder_norm0 (BatchNormal  (None, 112, 9)            36
#  ization)
#
#  encoder_conv1 (Conv1D)      (None, 104, 9)            738
#
#  encoder_norm1 (BatchNormal  (None, 104, 9)            36
#  ization)
#
#  encoder_conv2 (Conv1D)      (None, 94, 10)            1000
#
#  encoder_norm2 (BatchNormal  (None, 94, 10)            40
#  ization)
#
#  flatten (Flatten)           (None, 940)               0
#
#  encoder_dense0 (Dense)      (None, 196)               184436
#
#  dropout (Dropout)           (None, 196)               0
#
#  encoder_dense0_norm (Batch  (None, 196)               784
#  Normalization)
#
#  z_mean_sample (Dense)       (None, 196)               38612
#
# =================================================================
# Total params: 228526 (892.68 KB)
# Trainable params: 228078 (890.93 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# None
# ----------------------------------------------------------
# Decoder:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  decoder_input (InputLayer)  [(None, 196)]                0         []
#
#  decoder_dense0 (Dense)      (None, 196)                  38612     ['decoder_input[0][0]']
#
#  dropout_1 (Dropout)         (None, 196)                  0         ['decoder_dense0[0][0]']
#
#  decoder_dense0_norm (Batch  (None, 196)                  784       ['dropout_1[0][0]']
#  Normalization)
#
#  repeat_vector (RepeatVecto  (None, 120, 196)             0         ['decoder_dense0_norm[0][0]']
#  r)
#
#  decoder_gru0 (GRU)          (None, 120, 488)             1002840   ['repeat_vector[0][0]']
#
#  decoder_gru1 (GRU)          (None, 120, 488)             1430328   ['decoder_gru0[0][0]']
#
#  decoder_gru2 (GRU)          (None, 120, 488)             1430328   ['decoder_gru1[0][0]']
#
#  decoder_true_seq_input (In  [(None, 120, 35)]            0         []
#  putLayer)
#
#  decoder_tgru (TerminalGRU)  (None, None, 35)             56280     ['decoder_gru2[0][0]',
#                                                                      'decoder_true_seq_input[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 3959172 (15.10 MB)
# Trainable params: 3958780 (15.10 MB)
# Non-trainable params: 392 (1.53 KB)
# __________________________________________________________________________________________________
# None
# ----------------------------------------------------------
# Property Predictor:
# Model: "property_predictor"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prop_pred_input (InputLaye  [(None, 196)]             0
#  r)
#
#  dense (Dense)               (None, 67)                13199
#
#  dropout_2 (Dropout)         (None, 67)                0
#
#  property_predictor_dense1   (None, 66)                4488
#  (Dense)
#
#  dropout_3 (Dropout)         (None, 66)                0
#
#  batch_normalization (Batch  (None, 66)                264
#  Normalization)
#
#  property_predictor_dense2   (None, 65)                4355
#  (Dense)
#
#  dropout_4 (Dropout)         (None, 65)                0
#
#  batch_normalization_1 (Bat  (None, 65)                260
#  chNormalization)
#
#  reg_property_output (Dense  (None, 3)                 198
#  )
#
# =================================================================
# Total params: 22764 (88.92 KB)
# Trainable params: 22502 (87.90 KB)
# Non-trainable params: 262 (1.02 KB)
# _________________________________________________________________
# None

# %% [markdown]
# # QM9 Models

# %%
vae_qm9 = VAEUtils(directory='./qm9')
vae_qm9_prop = VAEUtils(directory='./qm9_properties')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2026-03-05 14:24:59.546103: W tensorflow/c/c_api.cc:305] Operation '{name:'encoder_dense0_norm_4/gamma/Assign' id:9369 op device:{requested: '', assigned: ''} def:{{{node encoder_dense0_norm_4/gamma/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](encoder_dense0_norm_4/gamma, encoder_dense0_norm_4/gamma/Initializer/ones)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:`implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# `implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# WARNING:tensorflow:Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2026-03-05 14:25:00.074428: W tensorflow/c/c_api.cc:305] Operation '{name:'decoder_dense0_4/bias/Assign' id:9593 op device:{requested: '', assigned: ''} def:{{{node decoder_dense0_4/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](decoder_dense0_4/bias, decoder_dense0_4/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Using standarized functions? True
# Standarization: estimating mu and std values ...
# 2026-03-05 14:25:00.378403: W tensorflow/c/c_api.cc:305] Operation '{name:'z_mean_sample_4/BiasAdd' id:9471 op device:{requested: '', assigned: ''} def:{{{node z_mean_sample_4/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](z_mean_sample_4/MatMul, z_mean_sample_4/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# done!
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2026-03-05 14:25:04.534132: W tensorflow/c/c_api.cc:305] Operation '{name:'encoder_norm1_5/beta/Assign' id:11199 op device:{requested: '', assigned: ''} def:{{{node encoder_norm1_5/beta/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](encoder_norm1_5/beta, encoder_norm1_5/beta/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:`implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# `implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# WARNING:tensorflow:Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2026-03-05 14:25:05.106062: W tensorflow/c/c_api.cc:305] Operation '{name:'decoder_gru2_5/gru_cell/kernel/Assign' id:12133 op device:{requested: '', assigned: ''} def:{{{node decoder_gru2_5/gru_cell/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](decoder_gru2_5/gru_cell/kernel, decoder_gru2_5/gru_cell/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Using standarized functions? True
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2026-03-05 14:25:05.553851: W tensorflow/c/c_api.cc:305] Operation '{name:'property_predictor_dense2_2/bias/Assign' id:13288 op device:{requested: '', assigned: ''} def:{{{node property_predictor_dense2_2/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](property_predictor_dense2_2/bias, property_predictor_dense2_2/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Standarization: estimating mu and std values ...
# 2026-03-05 14:25:05.821742: W tensorflow/c/c_api.cc:305] Operation '{name:'z_mean_sample_5/BiasAdd' id:11533 op device:{requested: '', assigned: ''} def:{{{node z_mean_sample_5/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](z_mean_sample_5/MatMul, z_mean_sample_5/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# done!

# %% [markdown]
# ## Without property prediction

# %%
print("Encoder:")
print(vae_qm9.enc.summary())
print("----------------------------------------------------------")
print("Decoder:")
print(vae_qm9.dec.summary())
# Out:
# Encoder:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_molecule_smi (InputL  [(None, 34, 22)]          0
#  ayer)
#
#  encoder_conv0 (Conv1D)      (None, 30, 2)             222
#
#  encoder_norm0 (BatchNormal  (None, 30, 2)             8
#  ization)
#
#  encoder_conv1 (Conv1D)      (None, 26, 2)             22
#
#  encoder_norm1 (BatchNormal  (None, 26, 2)             8
#  ization)
#
#  encoder_conv2 (Conv1D)      (None, 23, 1)             9
#
#  encoder_norm2 (BatchNormal  (None, 23, 1)             4
#  ization)
#
#  flatten (Flatten)           (None, 23)                0
#
#  encoder_dense0 (Dense)      (None, 156)               3744
#
#  dropout (Dropout)           (None, 156)               0
#
#  encoder_dense0_norm (Batch  (None, 156)               624
#  Normalization)
#
#  z_mean_sample (Dense)       (None, 156)               24492
#
# =================================================================
# Total params: 29133 (113.80 KB)
# Trainable params: 28811 (112.54 KB)
# Non-trainable params: 322 (1.26 KB)
# _________________________________________________________________
# None
# ----------------------------------------------------------
# Decoder:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  decoder_input (InputLayer)  [(None, 156)]                0         []
#
#  decoder_dense0 (Dense)      (None, 156)                  24492     ['decoder_input[0][0]']
#
#  dropout_1 (Dropout)         (None, 156)                  0         ['decoder_dense0[0][0]']
#
#  decoder_dense0_norm (Batch  (None, 156)                  624       ['dropout_1[0][0]']
#  Normalization)
#
#  repeat_vector (RepeatVecto  (None, 34, 156)              0         ['decoder_dense0_norm[0][0]']
#  r)
#
#  decoder_gru0 (GRU)          (None, 34, 488)              944280    ['repeat_vector[0][0]']
#
#  decoder_gru1 (GRU)          (None, 34, 488)              1430328   ['decoder_gru0[0][0]']
#
#  decoder_gru2 (GRU)          (None, 34, 488)              1430328   ['decoder_gru1[0][0]']
#
#  decoder_true_seq_input (In  [(None, 34, 22)]             0         []
#  putLayer)
#
#  decoder_tgru (TerminalGRU)  (None, None, 22)             34232     ['decoder_gru2[0][0]',
#                                                                      'decoder_true_seq_input[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 3864284 (14.74 MB)
# Trainable params: 3863972 (14.74 MB)
# Non-trainable params: 312 (1.22 KB)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## With property prediction

# %%
print("Encoder:")
print(vae_qm9_prop.enc.summary())
print("----------------------------------------------------------")
print("Decoder:")
print(vae_qm9_prop.dec.summary())
print("----------------------------------------------------------")
print("Property Predictor:")
print(vae_qm9_prop.property_predictor.summary())
# Out:
# Encoder:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_molecule_smi (InputL  [(None, 34, 22)]          0
#  ayer)
#
#  encoder_conv0 (Conv1D)      (None, 30, 2)             222
#
#  encoder_norm0 (BatchNormal  (None, 30, 2)             8
#  ization)
#
#  encoder_conv1 (Conv1D)      (None, 26, 2)             22
#
#  encoder_norm1 (BatchNormal  (None, 26, 2)             8
#  ization)
#
#  encoder_conv2 (Conv1D)      (None, 23, 1)             9
#
#  encoder_norm2 (BatchNormal  (None, 23, 1)             4
#  ization)
#
#  flatten (Flatten)           (None, 23)                0
#
#  encoder_dense0 (Dense)      (None, 156)               3744
#
#  dropout (Dropout)           (None, 156)               0
#
#  encoder_dense0_norm (Batch  (None, 156)               624
#  Normalization)
#
#  z_mean_sample (Dense)       (None, 156)               24492
#
# =================================================================
# Total params: 29133 (113.80 KB)
# Trainable params: 28811 (112.54 KB)
# Non-trainable params: 322 (1.26 KB)
# _________________________________________________________________
# None
# ----------------------------------------------------------
# Decoder:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  decoder_input (InputLayer)  [(None, 156)]                0         []
#
#  decoder_dense0 (Dense)      (None, 156)                  24492     ['decoder_input[0][0]']
#
#  dropout_1 (Dropout)         (None, 156)                  0         ['decoder_dense0[0][0]']
#
#  decoder_dense0_norm (Batch  (None, 156)                  624       ['dropout_1[0][0]']
#  Normalization)
#
#  repeat_vector (RepeatVecto  (None, 34, 156)              0         ['decoder_dense0_norm[0][0]']
#  r)
#
#  decoder_gru0 (GRU)          (None, 34, 488)              944280    ['repeat_vector[0][0]']
#
#  decoder_gru1 (GRU)          (None, 34, 488)              1430328   ['decoder_gru0[0][0]']
#
#  decoder_gru2 (GRU)          (None, 34, 488)              1430328   ['decoder_gru1[0][0]']
#
#  decoder_true_seq_input (In  [(None, 34, 22)]             0         []
#  putLayer)
#
#  decoder_tgru (TerminalGRU)  (None, None, 22)             34232     ['decoder_gru2[0][0]',
#                                                                      'decoder_true_seq_input[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 3864284 (14.74 MB)
# Trainable params: 3863972 (14.74 MB)
# Non-trainable params: 312 (1.22 KB)
# __________________________________________________________________________________________________
# None
# ----------------------------------------------------------
# Property Predictor:
# Model: "property_predictor"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prop_pred_input (InputLaye  [(None, 156)]             0
#  r)
#
#  dense (Dense)               (None, 67)                10519
#
#  dropout_2 (Dropout)         (None, 67)                0
#
#  property_predictor_dense1   (None, 66)                4488
#  (Dense)
#
#  dropout_3 (Dropout)         (None, 66)                0
#
#  batch_normalization (Batch  (None, 66)                264
#  Normalization)
#
#  property_predictor_dense2   (None, 65)                4355
#  (Dense)
#
#  dropout_4 (Dropout)         (None, 65)                0
#
#  batch_normalization_1 (Bat  (None, 65)                260
#  chNormalization)
#
#  reg_property_output (Dense  (None, 3)                 198
#  )
#
# =================================================================
# Total params: 20084 (78.45 KB)
# Trainable params: 19822 (77.43 KB)
# Non-trainable params: 262 (1.02 KB)
# _________________________________________________________________
# None

# %% [markdown]
# # ZINC Michael models

# %%
vae_zinc_michael = VAEUtils(directory='../models/zinc-michael')
vae_zinc_michael_prop = VAEUtils(directory='../models/zinc-michael_properties')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2026-03-05 14:25:16.964990: W tensorflow/c/c_api.cc:305] Operation '{name:'encoder_norm0_6/beta/Assign' id:13518 op device:{requested: '', assigned: ''} def:{{{node encoder_norm0_6/beta/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](encoder_norm0_6/beta, encoder_norm0_6/beta/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:`implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# `implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# WARNING:tensorflow:Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2026-03-05 14:25:17.576003: W tensorflow/c/c_api.cc:305] Operation '{name:'decoder_dense0_6/kernel/Assign' id:14081 op device:{requested: '', assigned: ''} def:{{{node decoder_dense0_6/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](decoder_dense0_6/kernel, decoder_dense0_6/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Using standarized functions? True
# Standarization: estimating mu and std values ...
# 2026-03-05 14:25:18.576279: W tensorflow/c/c_api.cc:305] Operation '{name:'z_mean_sample_6/BiasAdd' id:13964 op device:{requested: '', assigned: ''} def:{{{node z_mean_sample_6/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](z_mean_sample_6/MatMul, z_mean_sample_6/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# done!
# 2026-03-05 14:25:23.060946: W tensorflow/c/c_api.cc:305] Operation '{name:'z_mean_sample_7/kernel/Assign' id:16016 op device:{requested: '', assigned: ''} def:{{{node z_mean_sample_7/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](z_mean_sample_7/kernel, z_mean_sample_7/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru0 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_gru2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:`implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# `implementation=0` has been deprecated, and now defaults to `implementation=2`.Please update your layer call.
# WARNING:tensorflow:Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Layer decoder_tgru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2026-03-05 14:25:23.718243: W tensorflow/c/c_api.cc:305] Operation '{name:'decoder_gru1_7/gru_cell/recurrent_kernel/Assign' id:16468 op device:{requested: '', assigned: ''} def:{{{node decoder_gru1_7/gru_cell/recurrent_kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](decoder_gru1_7/gru_cell/recurrent_kernel, decoder_gru1_7/gru_cell/recurrent_kernel/Initializer/mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Using standarized functions? True
# 2026-03-05 14:25:24.259294: W tensorflow/c/c_api.cc:305] Operation '{name:'batch_normalization_4/gamma/Assign' id:17684 op device:{requested: '', assigned: ''} def:{{{node batch_normalization_4/gamma/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](batch_normalization_4/gamma, batch_normalization_4/gamma/Initializer/ones)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Standarization: estimating mu and std values ...
# 2026-03-05 14:25:25.233913: W tensorflow/c/c_api.cc:305] Operation '{name:'z_mean_sample_7/BiasAdd' id:16026 op device:{requested: '', assigned: ''} def:{{{node z_mean_sample_7/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](z_mean_sample_7/MatMul, z_mean_sample_7/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# done!

# %%
print("Encoder:")
print(vae_zinc_michael.enc.summary())
print("----------------------------------------------------------")
print("Decoder:")
print(vae_zinc_michael.dec.summary())
# Out:
# Encoder:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_molecule_smi (InputL  [(None, 84, 31)]          0
#  ayer)
#
#  encoder_conv0 (Conv1D)      (None, 76, 9)             2520
#
#  encoder_norm0 (BatchNormal  (None, 76, 9)             36
#  ization)
#
#  encoder_conv1 (Conv1D)      (None, 68, 9)             738
#
#  encoder_norm1 (BatchNormal  (None, 68, 9)             36
#  ization)
#
#  encoder_conv2 (Conv1D)      (None, 58, 10)            1000
#
#  encoder_norm2 (BatchNormal  (None, 58, 10)            40
#  ization)
#
#  flatten (Flatten)           (None, 580)               0
#
#  encoder_dense0 (Dense)      (None, 196)               113876
#
#  dropout (Dropout)           (None, 196)               0
#
#  encoder_dense0_norm (Batch  (None, 196)               784
#  Normalization)
#
#  z_mean_sample (Dense)       (None, 196)               38612
#
# =================================================================
# Total params: 157642 (615.79 KB)
# Trainable params: 157194 (614.04 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# None
# ----------------------------------------------------------
# Decoder:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  decoder_input (InputLayer)  [(None, 196)]                0         []
#
#  decoder_dense0 (Dense)      (None, 196)                  38612     ['decoder_input[0][0]']
#
#  dropout_1 (Dropout)         (None, 196)                  0         ['decoder_dense0[0][0]']
#
#  decoder_dense0_norm (Batch  (None, 196)                  784       ['dropout_1[0][0]']
#  Normalization)
#
#  repeat_vector (RepeatVecto  (None, 84, 196)              0         ['decoder_dense0_norm[0][0]']
#  r)
#
#  decoder_gru0 (GRU)          (None, 84, 488)              1002840   ['repeat_vector[0][0]']
#
#  decoder_gru1 (GRU)          (None, 84, 488)              1430328   ['decoder_gru0[0][0]']
#
#  decoder_gru2 (GRU)          (None, 84, 488)              1430328   ['decoder_gru1[0][0]']
#
#  decoder_true_seq_input (In  [(None, 84, 31)]             0         []
#  putLayer)
#
#  decoder_tgru (TerminalGRU)  (None, None, 31)             49352     ['decoder_gru2[0][0]',
#                                                                      'decoder_true_seq_input[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 3952244 (15.08 MB)
# Trainable params: 3951852 (15.08 MB)
# Non-trainable params: 392 (1.53 KB)
# __________________________________________________________________________________________________
# None

# %%
print("Encoder:")
print(vae_zinc_michael_prop.enc.summary())
print("----------------------------------------------------------")
print("Decoder:")
print(vae_zinc_michael_prop.dec.summary())
print("----------------------------------------------------------")
print("Property Predictor:")
print(vae_zinc_michael_prop.property_predictor.summary())
# Out:
# Encoder:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_molecule_smi (InputL  [(None, 84, 31)]          0
#  ayer)
#
#  encoder_conv0 (Conv1D)      (None, 76, 9)             2520
#
#  encoder_norm0 (BatchNormal  (None, 76, 9)             36
#  ization)
#
#  encoder_conv1 (Conv1D)      (None, 68, 9)             738
#
#  encoder_norm1 (BatchNormal  (None, 68, 9)             36
#  ization)
#
#  encoder_conv2 (Conv1D)      (None, 58, 10)            1000
#
#  encoder_norm2 (BatchNormal  (None, 58, 10)            40
#  ization)
#
#  flatten (Flatten)           (None, 580)               0
#
#  encoder_dense0 (Dense)      (None, 196)               113876
#
#  dropout (Dropout)           (None, 196)               0
#
#  encoder_dense0_norm (Batch  (None, 196)               784
#  Normalization)
#
#  z_mean_sample (Dense)       (None, 196)               38612
#
# =================================================================
# Total params: 157642 (615.79 KB)
# Trainable params: 157194 (614.04 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# None
# ----------------------------------------------------------
# Decoder:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  decoder_input (InputLayer)  [(None, 196)]                0         []
#
#  decoder_dense0 (Dense)      (None, 196)                  38612     ['decoder_input[0][0]']
#
#  dropout_1 (Dropout)         (None, 196)                  0         ['decoder_dense0[0][0]']
#
#  decoder_dense0_norm (Batch  (None, 196)                  784       ['dropout_1[0][0]']
#  Normalization)
#
#  repeat_vector (RepeatVecto  (None, 84, 196)              0         ['decoder_dense0_norm[0][0]']
#  r)
#
#  decoder_gru0 (GRU)          (None, 84, 488)              1002840   ['repeat_vector[0][0]']
#
#  decoder_gru1 (GRU)          (None, 84, 488)              1430328   ['decoder_gru0[0][0]']
#
#  decoder_gru2 (GRU)          (None, 84, 488)              1430328   ['decoder_gru1[0][0]']
#
#  decoder_true_seq_input (In  [(None, 84, 31)]             0         []
#  putLayer)
#
#  decoder_tgru (TerminalGRU)  (None, None, 31)             49352     ['decoder_gru2[0][0]',
#                                                                      'decoder_true_seq_input[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 3952244 (15.08 MB)
# Trainable params: 3951852 (15.08 MB)
# Non-trainable params: 392 (1.53 KB)
# __________________________________________________________________________________________________
# None
# ----------------------------------------------------------
# Property Predictor:
# Model: "property_predictor"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prop_pred_input (InputLaye  [(None, 196)]             0
#  r)
#
#  dense (Dense)               (None, 67)                13199
#
#  dropout_2 (Dropout)         (None, 67)                0
#
#  property_predictor_dense1   (None, 66)                4488
#  (Dense)
#
#  dropout_3 (Dropout)         (None, 66)                0
#
#  batch_normalization (Batch  (None, 66)                264
#  Normalization)
#
#  property_predictor_dense2   (None, 65)                4355
#  (Dense)
#
#  dropout_4 (Dropout)         (None, 65)                0
#
#  batch_normalization_1 (Bat  (None, 65)                260
#  chNormalization)
#
#  reg_property_output (Dense  (None, 3)                 198
#  )
#
# =================================================================
# Total params: 22764 (88.92 KB)
# Trainable params: 22502 (87.90 KB)
# Non-trainable params: 262 (1.02 KB)
# _________________________________________________________________
# None
